# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("housing.csv")
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['RM', 'LSTAT', 'PTRATIO', 'MEDV'], dtype='str')

# %%
x = df[['RM', 'LSTAT', 'PTRATIO']]
y = df["MEDV"]
# Out:
# 0      504000.0
# 1      453600.0
# 2      728700.0
# 3      701400.0
# 4      760200.0
#          ...
# 484    470400.0
# 485    432600.0
# 486    501900.0
# 487    462000.0
# 488    249900.0
# Name: MEDV, Length: 489, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([423754.02161618, 679187.92596745, 309195.43036712, 396504.8679217 ,
#        529742.51262779, 363346.69410844, 241462.6731427 , 415397.90037657,
#        477306.42543171, 375021.98878215, 323550.55220021, 359757.89403785,
#        476408.02736266,  55352.09477743, 487350.27270576, 315789.38870903,
#        466003.07244275, 613659.81026076, 384894.59771176, 652253.36694444,
#        670235.19765705, 651666.31378882,  17661.65614876, 456965.45045933,
#        364210.54686629, 749920.27724748, 709010.06992177, 749901.13507441,
#        431623.55249695, 424694.16886529, 377144.21247931, 461623.08268962,
#        474031.05539624, 679631.11323298, 458111.00822409, 762865.17690652,
#        522205.62388654, 263222.38767667, 504379.52150544, 591356.53264595,
#        324003.93209507, 448596.81036447, 404793.96471501, 500100.14668174,
#        282906.2227122 , 368630.6209711 , 526413.75562132, 361979.64130439,
#        711440.93020253, 409765.49243693, 677735.63535804, 448784.68641472,
#        614178.06767399, 379465.48800074, 658754.61972987, 584441.32436927,
#        360030.91059323, 314895.68918849, 487789.71470673, 446119.46946191,
#        455982.80938894, 364813.69202109, 413111.90493479, 411852.86571878,
#        387191.51491808, 360490.47447235, 235985.38812075, 553511.91666553,
#        578647.512431  , 310782.73168526,  66924.0484922 , 556837.45098468,
#        356108.41290988, 565027.76894447, 375661.55158224, 433981.18166377,
#        563576.58728588, 434318.22557633, 570426.08214309, 390428.19810842,
#        389898.79926388, 694219.90213286, 453650.10283808, 497727.93028991,
#        507859.23442226, 655477.60734585, 562896.6397155 , 524111.17700797,
#        447943.17229965, 446419.87461293, 449854.42585633, 283411.82464354,
#        353923.67235761, 421487.96053483, 556973.01935755, 525479.38268012,
#        440111.39974819, 602169.16426446, 417148.6347367 , 299518.19718436,
#        275177.63575098, 315098.66671232, 604366.7394877 , 448418.38730031,
#        395158.09954186, 202940.22810856, 497332.10615997, 447259.85604428,
#        347173.68796098, 598577.52870307, 624931.30897578, 452905.9130239 ,
#        358940.73450012, 639273.9188328 , 576177.02044446, 509235.32469924,
#        361485.71160133, 473858.20735402, 363770.39945588, 739215.02643428,
#        689506.22289207, 402196.60561775, 364925.87211474])

# %%
model.score(x_train, y_train)   #Testing Accuracy of model
# Out:
# 0.72961525700365

# %%
model.score(x_test, y_test)
# Out:
# 0.687026296346364

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# np.float64(99365.42903916586)

# %%
plt.scatter(y_test, y_pred, c='green')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.show()
